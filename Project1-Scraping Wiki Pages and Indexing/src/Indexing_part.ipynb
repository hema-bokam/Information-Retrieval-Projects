# %%
# !pip install pysolr --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pysolr in ./.local/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/lib/python3/dist-packages (from pysolr) (2.28.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from pysolr) (66.1.1)

# %%
# !pip install pandas --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 38.8 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy>=1.23.2 in /usr/lib/python3/dist-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.7.1)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 46.4 MB/s eta 0:00:00
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.3 tzdata-2024.2

# %%
import sys
print(sys.executable)
# Out:
# /home/hemabokam_3/.local/pipx/venvs/notebook/bin/python

# %%
import json
import os
import pysolr
import requests
import pandas as pd

CORE_NAME = "IRF24P1"
VM_IP = "34.85.223.192"

# %%
def delete_core(core=CORE_NAME):
    print(os.system('sudo su - solr -c "/opt/solr/bin/solr delete -c {core}"'.format(core=core)))


def create_core(core=CORE_NAME):
    print(os.system(
        'sudo su - solr -c "/opt/solr/bin/solr create -c {core} -n data_driven_schema_configs"'.format(
            core=core)))

# %%
import pysolr
import requests

class Indexer:
    def __init__(self):
        self.solr_url = f'http://{VM_IP}:8983/solr/'
        self.connection = pysolr.Solr(self.solr_url + CORE_NAME, always_commit=True, timeout=5000000)

    def do_initial_setup(self):
        delete_core()
        create_core()

    def create_documents(self, docs):
        print(self.connection.add(docs))

    def add_fields(self):
        data = {
            "add-field": [
                {
                    "name": "title",
                    "type": "string",
                    "indexed": True,
                    "multiValued": False
                },
                {
                    "name": "revision_id",
                    "type": "string",
                    "multiValued": False
                },
                {
                    "name": "summary",
                    "type": "text_en",
                    "indexed": True,
                    "multiValued": False
                },
                {
                    "name": "url",
                    "type": "string",
                    "multiValued": False
                },
                {
                    "name": "topic",
                    "type": "string",
                    "indexed": False,
                    "multiValued": False
                }
            ]
        }

        print("Sending request to:", self.solr_url + CORE_NAME + "/schema")
        response = requests.post(self.solr_url + CORE_NAME + "/schema", json=data)

# %%
with open('preprocessed_documents.json', 'r') as json_file:
    data = json.load(json_file)
df = pd.DataFrame(data)

df
# Out:
#                                                 Health  \
# 0    {'revision_id': '1242625743', 'title': 'Diseas...
# 1    {'revision_id': '1234079069', 'title': 'Climat...
# 2    {'revision_id': '1245543298', 'title': 'Diseas...
# 3    {'revision_id': '1246076854', 'title': 'Autoim...
# 4    {'revision_id': '1230154098', 'title': 'Lists ...
# ..                                                 ...
# 515  {'revision_id': '1242053264', 'title': 'PeaceH...
# 516  {'revision_id': '1246650933', 'title': 'Indian...
# 517  {'revision_id': '1247510539', 'title': 'Hospit...
# 518  {'revision_id': '1246150931', 'title': 'Scripp...
# 519  {'revision_id': '1241469772', 'title': 'Hospit...
#
#                                            Environment  \
# 0    {'revision_id': '1162488843', 'title': 'Climat...
# 1    {'revision_id': '1247920196', 'title': 'List o...
# 2    {'revision_id': '1247759022', 'title': 'List o...
# 3    {'revision_id': '1243517381', 'title': 'Climat...
# 4    {'revision_id': '1247060311', 'title': 'Climat...
# ..                                                 ...
# 515  {'revision_id': '1192017585', 'title': 'Roy Sp...
# 516  {'revision_id': '1246212917', 'title': 'Develo...
# 517  {'revision_id': '1246348522', 'title': 'Albedo...
# 518  {'revision_id': '1245999197', 'title': 'Patric...
# 519  {'revision_id': '1243369959', 'title': 'Bøllin...
#
#                                             Technology  \
# 0    {'revision_id': '1163229447', 'title': 'Certif...
# 1    {'revision_id': '1247282330', 'title': 'Comput...
# 2    {'revision_id': '1248105655', 'title': 'Comput...
# 3    {'revision_id': '1213103775', 'title': 'End-us...
# 4    {'revision_id': '1247283925', 'title': 'Quantu...
# ..                                                 ...
# 515  {'revision_id': '1225182924', 'title': 'Shibbo...
# 516  {'revision_id': '1247293121', 'title': 'Perfor...
# 517  {'revision_id': '1245153789', 'title': 'Offsho...
# 518  {'revision_id': '1214232625', 'title': 'Ocean ...
# 519  {'revision_id': '1242700233', 'title': 'GraphP...
#
#                                                Economy  \
# 0    {'revision_id': '1176565195', 'title': 'Foreig...
# 1    {'revision_id': '1224551402', 'title': 'Curren...
# 2    {'revision_id': '1240844627', 'title': 'Day tr...
# 3    {'revision_id': '1132933300', 'title': 'Job an...
# 4    {'revision_id': '1164751035', 'title': 'Short-...
# ..                                                 ...
# 515  {'revision_id': '1245392979', 'title': 'Colomb...
# 516  {'revision_id': '1227948421', 'title': 'Public...
# 517  {'revision_id': '1247709156', 'title': 'Public...
# 518  {'revision_id': '1220711157', 'title': 'Margin...
# 519  {'revision_id': '1248042712', 'title': 'NIFTY ...
#
#                                          Entertainment  \
# 0    {'revision_id': '1242999643', 'title': 'Music ...
# 1    {'revision_id': '1247890963', 'title': 'Music ...
# 2    {'revision_id': '1247495880', 'title': 'Women ...
# 3    {'revision_id': '1207589318', 'title': 'Bachel...
# 4    {'revision_id': '1247770780', 'title': '2000s ...
# ..                                                 ...
# 515  {'revision_id': '1238836651', 'title': 'Broadc...
# 516  {'revision_id': '1247148492', 'title': 'Almost...
# 517  {'revision_id': '1247564688', 'title': 'OnlyFa...
# 518  {'revision_id': '1236139886', 'title': 'Por Vi...
# 519  {'revision_id': '1247656579', 'title': 'Laxmii...
#
#                                                 Sports  \
# 0    {'revision_id': '1246481254', 'title': 'List o...
# 1    {'revision_id': '1247661618', 'title': 'Winter...
# 2    {'revision_id': '1247988021', 'title': 'Olympi...
# 3    {'revision_id': '1245612113', 'title': 'Olympi...
# 4    {'revision_id': '1247769655', 'title': '2008 S...
# ..                                                 ...
# 515  {'revision_id': '1247412123', 'title': 'AEW Ra...
# 516  {'revision_id': '1248080559', 'title': 'IRIB T...
# 517  {'revision_id': '1205006710', 'title': 'Alan C...
# 518  {'revision_id': '1243660600', 'title': 'Greens...
# 519  {'revision_id': '1233394666', 'title': 'Bro Go...
#
#                                               Politics  \
# 0    {'revision_id': '1247867284', 'title': 'Electi...
# 1    {'revision_id': '1247782765', 'title': '2020 U...
# 2    {'revision_id': '1244108235', 'title': 'Electi...
# 3    {'revision_id': '1243599923', 'title': '2020 U...
# 4    {'revision_id': '1248110564', 'title': 'United...
# ..                                                 ...
# 515  {'revision_id': '1248002441', 'title': 'Spain–...
# 516  {'revision_id': '1246932903', 'title': 'Minist...
# 517  {'revision_id': '1247837987', 'title': 'Foreig...
# 518  {'revision_id': '1241976940', 'title': 'Gareth...
# 519  {'revision_id': '1247180763', 'title': 'Walsh ...
#
#                                              Education  \
# 0    {'revision_id': '1247029362', 'title': 'Philos...
# 1    {'revision_id': '1247739712', 'title': 'Scienc...
# 2    {'revision_id': '1242921849', 'title': 'Scienc...
# 3    {'revision_id': '1235096314', 'title': 'Citize...
# 4    {'revision_id': '1242857195', 'title': 'List o...
# ..                                                 ...
# 515  {'revision_id': '1228319661', 'title': 'Educat...
# 516  {'revision_id': '1248003155', 'title': 'Stephe...
# 517  {'revision_id': '1244765698', 'title': 'Rivers...
# 518  {'revision_id': '1248097863', 'title': 'IIEST,...
# 519  {'revision_id': '1246073665', 'title': 'Randy ...
#
#                                                 Travel  \
# 0    {'revision_id': '1245092786', 'title': 'Beach'...
# 1    {'revision_id': '1248077941', 'title': 'World ...
# 2    {'revision_id': '1192741721', 'title': '2021 B...
# 3    {'revision_id': '1192741659', 'title': '2020 B...
# 4    {'revision_id': '1228798343', 'title': '2023 B...
# ..                                                 ...
# 515  {'revision_id': '1171735197', 'title': 'Escort...
# 516  {'revision_id': '1236976102', 'title': 'Travel...
# 517  {'revision_id': '1247004710', 'title': 'Robert...
# 518  {'revision_id': '1244509743', 'title': 'Cliffo...
# 519  {'revision_id': '1247888119', 'title': 'Unnale...
#
#                                                   Food
# 0    {'revision_id': '1247961753', 'title': 'Food s...
# 1    {'revision_id': '1242003337', 'title': 'Climac...
# 2    {'revision_id': '1244506033', 'title': 'List o...
# 3    {'revision_id': '1247243821', 'title': 'Malnut...
# 4    {'revision_id': '1247728817', 'title': 'Organi...
# ..                                                 ...
# 515  {'revision_id': '1244401855', 'title': 'Ethyle...
# 516  {'revision_id': '1245694243', 'title': 'Superf...
# 517  {'revision_id': '1122922693', 'title': 'Premie...
# 518  {'revision_id': '1244150347', 'title': 'Candie...
# 519  {'revision_id': '1174462863', 'title': 'Fruit ...
#
# [520 rows x 10 columns]

# %%
i = Indexer()
i.do_initial_setup()
i.add_fields()
# Out:
# /etc/default/solr.in.sh: line 311: i: command not found
# Neither --zk-host or --solr-url parameters provided so assuming solr url is http://localhost:8983.
# Deleting core 'IRF24P1' using CoreAdminRequest
#
# 256
# ERROR: Error from server at http://localhost:8983/solr/admin/cores?action=UNLOAD&core=IRF24P1&indexInfo=true&deleteIndex=true&deleteDataDir=true&deleteInstanceDir=true&wt=json&version=2.2: null
# request: GET
#
# Error returned:
# {
#   "responseHeader":{
#     "status":400,
#     "QTime":11
#   },
#   "error":{
#     "metadata":["error-class","org.apache.solr.common.SolrException","root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Cannot unload non-existent core [IRF24P1]",
#     "code":400
#   }
# }
#
# /etc/default/solr.in.sh: line 311: i: command not found
# Neither --zk-host or --solr-url parameters provided so assuming solr url is http://localhost:8983.
# WARNING: Using _default configset. Data driven schema functionality is enabled by default, which is
#          NOT RECOMMENDED for production use.
#
#          To turn it off:
#             curl http://localhost:8983/solr/IRF24P1/config -d '{"set-user-property": {"update.autoCreateFields":"false"}}'
#          Or:
#             bin/solr config -c IRF24P1 -s http://localhost:8983 --action set-user-property --property update.autoCreateFields --value false
#
# Created new core 'IRF24P1'
# 0
# Sending request to: http://34.85.223.192:8983/solr/IRF24P1/schema
# {'responseHeader': {'status': 0, 'QTime': 1216}}

# %%
# Index the sample dataset
collection = df.to_dict('records')
i.create_documents(collection)
# Out:
# {
#   "responseHeader":{
#     "status":0,
#     "QTime":5606
#   }
# }
